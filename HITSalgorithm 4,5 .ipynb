# %% [markdown]
# <a href="https://colab.research.google.com/github/Darshini-A/Social-Network-Analysis/blob/main/HITSalgorithm%204%2C5%20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 4
# HITS algorithm to know the hubs and authorities count

# %%
import networkx as nx

G = nx.DiGraph()
G.add_edges_from([(1, 2), (1, 3), (2, 4), (3, 4), (4, 5)])

authority_scores, hub_scores = nx.hits(G)

print("Authority Scores -", authority_scores)
print("Hub Scores -", hub_scores)
# Out:
# Authority Scores - {1: 0.8797448275807949, 2: 0.06012758620960267, 3: 0.06012758620960267, 4: -1.3877180412839223e-16, 5: 0.0}
# Hub Scores - {1: -1.4764961934433364e-16, 2: 0.4680128997684299, 3: 0.4680128997684299, 4: 0.06397420046314056, 5: -1.4764961934433369e-16}

# %%
# 5
# HITS algorithm to know the hubs and authorities count with graph

# %%
import networkx as nx
import matplotlib.pyplot as plt

G = nx.DiGraph()
G.add_edges_from([('A', 'D'), ('B', 'C'), ('B', 'E'), ('C', 'A'),
				('D', 'C'), ('E', 'D'), ('E', 'B'), ('E', 'F'),
				('E', 'C'), ('F', 'C'), ('F', 'H'), ('G', 'A'),
				('G', 'C'), ('H', 'A')])

plt.figure(figsize = (10, 10))
nx.draw_networkx(G, with_labels = True)

authorities, hubs = nx.hits(G, max_iter = 50, normalized = True)

print("Authority Scores -", authorities)
print("Hub Scores -", hubs)
# Out:
# Authority Scores - {'A': 0.046425404032199954, 'D': 0.1336603752611538, 'B': 0.1576359944296732, 'C': 0.037389132246426544, 'E': 0.2588144598468665, 'F': 0.1576359944296732, 'H': 0.037389132246426544, 'G': 0.17104950750758033}
# Hub Scores - {'A': 0.10864044011724346, 'D': 0.13489685434358004, 'B': 0.1143797407333645, 'C': 0.388372800387618, 'E': 0.06966521184241477, 'F': 0.1143797407333645, 'H': 0.06966521184241477, 'G': 3.230167073847029e-18}
